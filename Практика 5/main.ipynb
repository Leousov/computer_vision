# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import HTML
from moviepy.editor import VideoFileClip, ImageSequenceClip
import time
from sklearn.metrics import jaccard_score, f1_score

# Для DeepLabV3+
import torch
from torchvision import models

# Для U-Net/Segmentation Models
import segmentation_models_pytorch as smp

# Для Mask R-CNN (TensorFlow)
from tensorflow.keras.applications import MaskRCNN
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       3 import matplotlib.pyplot as plt
#       4 from IPython.display import HTML
# ----> 5 from moviepy.editor import VideoFileClip, ImageSequenceClip
#       6 import time
#       7 from sklearn.metrics import jaccard_score, f1_score
#
# ModuleNotFoundError: No module named 'moviepy.editor'
